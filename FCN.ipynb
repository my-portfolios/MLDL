# %%
# %tensorflow_version 1.x
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %%
train_imgs = np.load('/content/drive/My Drive/Colab Notebooks/data_files/images_training.npy')
train_seg = np.load('/content/drive/My Drive/Colab Notebooks/data_files/seg_training.npy')
test_imgs = np.load('/content/drive/My Drive/Colab Notebooks/data_files/images_testing.npy')

n_train = train_imgs.shape[0]
n_test = test_imgs.shape[0]

print ("The number of training images : {}, shape : {}".format(n_train, train_imgs.shape))
print ("The number of testing images : {}, shape : {}".format(n_test, test_imgs.shape))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ba6a744ddc03> in <module>()
# ----> 1 train_imgs = np.load('/content/drive/My Drive/Colab Notebooks/data_files/images_training.npy')
#       2 train_seg = np.load('/content/drive/My Drive/Colab Notebooks/data_files/seg_training.npy')
#       3 test_imgs = np.load('/content/drive/My Drive/Colab Notebooks/data_files/images_testing.npy')
#       4
#       5 n_train = train_imgs.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/data_files/images_training.npy'
